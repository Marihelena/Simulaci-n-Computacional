# %% [markdown]
# ## <center>DISTRIBUCIONES DISCRETAS<center>
# ## Distribucion Binomial

# %%
# %matplotlib inline 

import numpy as np
import scipy as sp
import math
import matplotlib.pyplot as plt
import scipy.integrate
n=10
b=[]
p=[]
bu=[]
acum=[]
#generador Aleatorio
def numalea():
    xo=7
    for i in range(n):
        mod=(223*xo+23)%829
        ui=float(mod)/829
        xo=mod
        p.append(ui)
    #print(p)
    return p
plt.subplot(3,1,1)

def binomial():
    p=numalea()
    for i in range(n):
        pr=(1-p[2])**(n-i)
        c=(math.factorial(n)/(math.factorial(i)*math.factorial(n-i)))*(p[2]**i)*pr
        b.append(c)
        #print(c)
    return b
plt.plot(binomial(),color="r",marker="o",linestyle="--")
plt.show()
plt.subplot(3,1,2)
def acumubino():
    g=0
    for i in range(n):
        g=b[i]+g
        acum.append(g)
    #print("Acumulada",acum)
    return acum
plt.plot(acumubino())
plt.show()

plt.subplot(3,1,3)
def inverbino():
    p=numalea()
    for i in range(n):
        for j in range(n):
            if p[i]<acum[j]:
                bu.append(j)
                break
    print("Valores Inversa Binomial",bu)
    return bu
plt.plot(inverbino())
plt.show()
# Out:
# ('Valores Inversa Binomial', [4, 1, 1, 3, 0, 2, 2, 2, 1, 3])

# %% [markdown]
# # Distribucion Geometrica

# %%
ll=[]
acumg=[]
def geometrica():
    p=numalea()
    for i in range(n):
        l=((1-p[2])**(i-1))*p[2]
        ll.append(l)
    #print(ll)
    return ll

plt.subplot(2,1,1)
def acumugeome():
    h=0
    for i in range(n):
        h=ll[i]+h
        acumg.append(h)
    #print("Acumulada",acum)
    return acumg

plt.plot(geometrica(),label="Geometrica",color="r",marker="o",linestyle="--")
plt.plot(acumugeome(), label="Acumulada")
plt.legend(loc="upper left")

plt.subplot(2,1,2)
bj=[]
def invergeo():
    p=numalea()
    for i in range(n):
        for j in range(n):
            if p[i]<acumg[j]:
                bj.append(j)
                break
    print("Valores Inversa Binomial",bj)
    return bj
plt.plot(invergeo(),marker="x")
plt.grid()
plt.show()
# Out:
# ('Valores Inversa Binomial', [6, 0, 0, 5, 0, 2, 3, 3, 0, 4])

# %% [markdown]
# ##Distribucion Uniforme discreta

# %%
lo=[]
acumu=[]
plt.subplot(3,1,1)
def unidiscreta():
    p=numalea()
    for i in range(n):
        u=1/float(n)
        lo.append(u)
    #print(ll)
    return lo
plt.plot(unidiscreta(),color="g",marker="o",linestyle="--")
plt.show()

plt.subplot(3,1,2)
def acumudis():
    hi=0
    for i in range(n):
        hi=lo[i]+hi
        acumu.append(hi)
    #print("Acumulada",acum)
    return acumu
plt.plot(acumudis())
plt.show()

plt.subplot(3,1,3)
bl=[]
def invergeo():
    p=numalea()
    for i in range(n):
        for j in range(n):
            if p[i]<acumu[j]:
                bl.append(j)
                break
    print("Valores Inversa Binomial",bl)
    return bl
plt.plot(invergeo(),marker="x")
plt.grid()
plt.show()
# Out:
# ('Valores Inversa Binomial', [9, 1, 1, 8, 0, 5, 6, 6, 1, 8])

# %% [markdown]
# # <center> Distribuciones Continuas <center>
# ## Distribucion Exponencial

# %%
lan=0.5
ae=[]
ie=[]
plt.subplot(2,1,1)
def exponencial(d):
    for i in range(n):
        f=d*math.exp(-d*i)
        ae.append(f)
    #print(ll)
    return ae
plt.plot(exponencial(0.5),color="c")
plt.show()
plt.subplot(2,1,2)
def inverexpo():
    
    for i in range(n):
        f=(-math.log(1-p[i]))/lan
        ie.append(f)
    print("Valore inversa DIS Exponencial",ie)
    return ie
    
plt.plot(inverexpo(), marker="x", color="g")
plt.show()
# Out:
# ('Valore inversa DIS Exponencial', [4.832310123862252, 0.2598382138772181, 0.43786096918981166, 4.151658511987844, 0.10652672541217684, 1.8062179903441815, 2.0664895975909503, 2.236202668511188, 0.2763900324849376, 3.327948699573974])

# %% [markdown]
# ## Distribucion Gamma

# %%
def gamma():
    for i in range(n):
        funga,e=quad(lambda x: math.pow(x,(i-1))*math.exp(-x),0,inf)
